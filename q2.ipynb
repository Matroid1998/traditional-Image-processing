# %%
from scipy import ndimage, misc 
import matplotlib.pyplot as plt
import numpy as np
from skimage.io import imread, imshow, show
import matplotlib.pylab as plt
from scipy.ndimage import affine_transform, zoom
from scipy import misc
import matplotlib
import matplotlib.pylab as pylab
from skimage.transform import AffineTransform

# %%
from google.colab import files
from IPython.display import Image

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-58df60ee-ac7c-420c-9e7c-22e8d19e12fa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-58df60ee-ac7c-420c-9e7c-22e8d19e12fa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving image2.jpg to image2.jpg

# %%
im2=imread("image2.jpg")

# %%
imshow(im2)

# %%
scaling= np.array([[1.5,0,0],[0,1.5,0],[0,0,1]])
scaling
# Out:
# array([[1.5, 0. , 0. ],
#        [0. , 1.5, 0. ],
#        [0. , 0. , 1. ]])

# %%
from scipy import ndimage
im2_scale=ndimage.affine_transform(im2,scaling)

# %%
imshow(im2_scale)

# %%
scale_bigger= np.array([[1/1.5,0,0],[0,1/1.5,0],[0,0,1]])
scale_bigger
# Out:
# array([[0.66666667, 0.        , 0.        ],
#        [0.        , 0.66666667, 0.        ],
#        [0.        , 0.        , 1.        ]])

# %%
im2_scale=ndimage.affine_transform(im2,scale_bigger)
imshow(im2_scale)

# %%
im2_rotated=ndimage.rotate(im2,90)
imshow(im2_rotated)

# %%
import cv2

# %%
height, width = im2.shape[:2]
new_height, new_width = height /4, width/4
T = np.float32([[1, 0, new_width], [0, 1, new_height]])
img_translation = cv2.warpAffine(im2, T, (width, height))
imshow(img_translation)
